# %% [markdown]
# # Final Model Predictions

# %% [markdown]
# ## The research paper mostly comparises of the folling different different classifiers
# | Abbreviation | Description                                       |
# |--------------|---------------------------------------------------|
# | **DT**       | Decision Trees                                    |
# | **ET**       | Extra Trees                                       |
# | **kNN**      | k-Nearest Neighbors                               |
# | **LDA**      | Linear Discriminant Analysis                      |
# | **R_SVM**    | Radial Basis Function Support Vector Machine      |
# | **L_SVM**    | Linear Support Vector Machine                     |
# | **LR**       | Logistic Regression                               |
# | **RF**       | Random Forest                                     |
#
# ## for the following parameters :
# - **linguistic**
# - **syntatic**
# - **symantic**
# - **Combined**

# %%
import pandas as pd 
df = pd.read_csv(r'data/final.csv' , header='infer')
df = df.drop(columns=['index'])

# %%
df_pdt = df[df['type']=='PDT']
df_srt = df[df['type']=='SRT']
print(df_pdt.shape)
print(df_srt.shape)
# Out:
# (58, 19)
# (66, 19)

# %%
df.describe()
# Out:
#        lexical_diversity  brunets_index  honors_statistic  \
# count         124.000000     124.000000        124.000000
# mean            0.563977     114.020347        -16.989671
# std             0.118170      66.004652         43.931742
# min             0.371429       5.273511       -390.308999
# 25%             0.483248      58.937523        -19.240180
# 50%             0.536522     104.382452        -11.223801
# 75%             0.633414     160.352224         -7.256763
# max             1.000000     367.819891        250.858330
#
#        flesch_kincaid_grade_level  flesch_reading_ease  ambigous_pronoun  \
# count                  124.000000           124.000000        124.000000
# mean                     5.514096            83.141273          6.104839
# std                      4.133973            15.947720          4.650061
# min                     -0.051165            18.141449          0.000000
# 25%                      2.928269            74.855000          2.000000
# ...

# %%
df[df['diagnosis']==0]
# Out:
#      lexical_diversity  brunets_index  honors_statistic  \
# 93            0.544118      76.909933        -23.973467
# 94            0.812500      20.242733        -49.560207
# 95            0.551020      56.011340        -28.839043
# 96            0.475285     150.884378         -9.910318
# 97            0.535032      88.615549        -18.807054
# 98            0.530435     166.447765         -3.951367
# 99            0.510917     157.135988         -6.102104
# 100           0.666667      47.254006        -23.593671
# 101           0.493776     162.454762         -5.785578
# 102           0.510040     163.828739         -6.860108
# 103           0.635417      66.068168        -13.421333
# 104           0.467577     188.168974         -6.366667
# 105           0.434944     174.794098         -6.515800
# 106           0.671329      92.010420        -13.493956
# 107           0.530249     191.655000         -5.334253
# 108           0.423881     212.868503         -6.786634
# ...
